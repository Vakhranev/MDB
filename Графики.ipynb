# %% [markdown]
# <a href="https://colab.research.google.com/github/Vakhranev/MDB/blob/main/%D0%93%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
groups = ["Group 1 vs Group 2", "Group 1 vs Group 3", "Group 1 vs Group 4", "Group 2 vs Group 3", "Group 2 vs Group 4", "Group 3 vs Group 4"]
mean_diff = [0.17, -0.25, -0.69, -0.44, -0.42, -0.86]
se = [0.18, 0.18, 0.19, 0.08, 0.04, 0.08]
p_values = ['.78', '.51', '<.01', '<.01', '<.01', '<.01']
hedges_g = ['.27', '-.30', '-.63', '-.57', '-.69', '-1.54']

# Calculating the confidence intervals for the mean differences
# Assuming a 95% confidence interval, z-score is approximately 1.96 for a two-tailed test
z_score = 1.96
conf_intervals = [(md - z_score * s, md + z_score * s) for md, s in zip(mean_diff, se)]

# Plotting
plt.figure(figsize=(10, 6))
for i, (group, ci, p, h) in enumerate(zip(groups, conf_intervals, p_values, hedges_g)):
    plt.plot(ci, [i, i], color="skyblue")
    plt.scatter(mean_diff[i], i, color="blue")
    plt.text(ci[1] + 0.05, i, f"p={p}\nHedges' g={h}", va='center')

# Aesthetic elements
plt.yticks(range(len(groups)), groups)
plt.axvline(0, color='grey', linestyle='--')
plt.xlabel("Mean Difference")
plt.title("Games-Howell Posthoc Test Results")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Результаты теста Геймса-Хауэла
groups = ["Group 1 vs Group 2", "Group 1 vs Group 3", "Group 1 vs Group 4", "Group 2 vs Group 3", "Group 2 vs Group 4", "Group 3 vs Group 4"]
mean_diff = [-0.083694, -0.190294, -0.294234, -0.106600, -0.210540, -0.103940]
se = [0.032516, 0.032370, 0.034824, 0.012065, 0.017620, 0.017349]
p_values = [".03", "<.01", "<.01", "<.01", "<.01", "<.01"]
hedges_g = ["-.43", "-1.01", "-1.46", "-.59", "-1.16", "-.59"]

# Результаты теста Геймса-Хауэла
results = pd.DataFrame({
    'group1': ['A1', 'A1', 'A1', 'A2', 'A2', 'B1'],
    'group2': ['A2', 'B1', 'B2', 'B1', 'B2', 'B2'],
    'mean(A)': [1.749754, 1.749754, 1.749754, 1.833448, 1.833448, 1.940048],
    'mean(B)': [1.833448, 1.940048, 2.043988, 1.940048, 2.043988, 2.043988],
    'diff': [-0.083694, -0.190294, -0.294234, -0.106600, -0.210540, -0.103940],
    'se': [0.032516, 0.032370, 0.034824, 0.012065, 0.017620, 0.017349],
    'T': [-2.573943, -5.878718, -8.449193, -8.835383, -11.949079, -5.991224],
    'df': [72.135241, 70.865441, 92.414095, 896.142046, 216.896667, 205.641673],
    'pval': [5.732806e-02, 7.362416e-07, 2.405298e-12, 5.973000e-14, 0.000000e+00, 5.500539e-08],
    'hedges': [-0.432094, -1.009965, -1.461955, -0.587227, -1.157857, -0.585654]
})

# Расчет доверительных интервалов
z_score = 1.96
conf_intervals = [
    (md - z_score * s, md + z_score * s) for md, s in zip(results['diff'], results['se'])
]

# Построение графика
plt.figure(figsize=(10, 6))
for i, (group, ci, p, h) in enumerate(zip(groups, conf_intervals, p_values, hedges_g)):
    plt.plot(ci, [i, i], color="skyblue")
    plt.scatter(mean_diff[i], i, color="blue")
    plt.text(ci[1] + 0.01, i, f"p={p}\nHedges' g={h}", va='center')

# Элементы оформления
plt.yticks(range(len(results)), results['group1'] + ' vs ' + results['group2'])
plt.axvline(0, color='grey', linestyle='--')
plt.xlabel("Mean Difference")
plt.title("Games-Howell Posthoc Test Results")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Результаты теста Геймса-Хауэла
groups = ["Group 1 vs Group 2", "Group 1 vs Group 3", "Group 1 vs Group 4", "Group 2 vs Group 3", "Group 2 vs Group 4", "Group 3 vs Group 4"]
mean_diff = [-0.190066, -0.338571, -0.451392, -0.148505, -0.261326, -0.112821]
se = [0.040389, 0.040041, 0.041116, 0.010445, 0.014012, 0.012974]
p_values = ["<.01", "<.01", "<.01", "<.01", "<.01", "<.01"]
hedges_g = ["-.97", "-2.01", "-2.16", "-.95", "-1.59", "-.83"]

# Результаты теста Геймса-Хауэла
games_howell_result = pd.DataFrame({
    'A': ['Group 1', 'Group 1', 'Group 1', 'Group 2', 'Group 2', 'Group 3'],
    'B': ['Group 2', 'Group 3', 'Group 4', 'Group 3', 'Group 4', 'Group 4'],
    'mean(A)': [1.788852, 1.788852, 1.788852, 1.978918, 1.978918, 2.127423],
    'mean(B)': [1.978918, 2.127423, 2.240244, 2.127423, 2.240244, 2.240244],
    'diff': [-0.190066, -0.338571, -0.451392, -0.148505, -0.261326, -0.112821],
    'se': [0.040389, 0.040041, 0.041116, 0.010445, 0.014012, 0.012974],
    'T': [-4.705880, -8.455687, -10.978615, -14.217170, -18.649753, -8.696019],
    'df': [67.541553, 65.252897, 72.315759, 834.226292, 274.697171, 212.870315],
    'pval': [7.534428e-05, 2.638956e-11, 0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00],
    'hedges': [-0.966799, -2.009505, -2.159490, -0.951199, -1.589954, -0.830153]
})

# Расчет доверительных интервалов
z_score = 1.96
conf_intervals = [
    (md - z_score * s, md + z_score * s) for md, s in zip(games_howell_result['diff'], games_howell_result['se'])
]

# Построение графика
plt.figure(figsize=(10, 6))
for i, (group, ci, p, h) in enumerate(zip(groups, conf_intervals, p_values, hedges_g)):
    plt.plot(ci, [i, i], color="skyblue")
    plt.scatter(mean_diff[i], i, color="blue")
    plt.text(ci[1] + 0.01, i, f"p={p}\nHedges' g={h}", va='center')

# Элементы оформления
plt.yticks(range(len(games_howell_result)), games_howell_result['A'] + ' vs ' + games_howell_result['B'])
plt.axvline(0, color='grey', linestyle='--')
plt.xlabel("Mean Difference")
plt.title("Games-Howell Posthoc Test Results")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Результаты теста Геймса-Хауэла
groups = ["Group 1 vs Group 2", "Group 1 vs Group 3", "Group 1 vs Group 4", "Group 2 vs Group 3", "Group 2 vs Group 4", "Group 3 vs Group 4"]
mean_diff = [-47.412481, -84.215589, -125.520560, -36.803108, -78.108079, -41.304971]
se = [3.428439, 3.540526, 5.028524, 3.098751, 4.727895, 4.809795]
p_values = ["<.01", "<.01", "<.01", "<.01", "<.01", "<.01"]
hedges_g = ["-1.13", "-1.79", "-3.05", "-.79", "-1.74", "-.84"]

# Расчет доверительных интервалов
z_score = 1.96
conf_intervals = [
    (md - z_score * s, md + z_score * s) for md, s in zip(mean_diff, se)
]

# Построение графика
plt.figure(figsize=(10, 6))
for i, (group, ci, p, h) in enumerate(zip(groups, conf_intervals, p_values, hedges_g)):
    plt.plot(ci, [i, i], color="skyblue")
    plt.scatter(mean_diff[i], i, color="blue")
    plt.text(ci[1] + 0.05, i, f"p={p}\nHedges' g={h}", va='center')

# Элементы оформления
plt.yticks(range(len(groups)), groups)
plt.axvline(0, color='grey', linestyle='--')
plt.xlabel("Mean Difference")
plt.title("Games-Howell Posthoc Test Results")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Результаты теста Геймса-Хауэла для новых данных
groups = ["Group 1 vs Group 2", "Group 1 vs Group 3", "Group 1 vs Group 4", "Group 2 vs Group 3", "Group 2 vs Group 4", "Group 3 vs Group 4"]
mean_diff = [-39.269515, -69.716892, -103.493313, -30.447377, -64.223798, -33.776422]
se = [3.009095, 3.077848, 4.161779, 2.545689, 3.785206, 3.840089]
p_values = ["<.01", "<.01", "<.01", "<.01", "<.01", "<.01"]
hedges_g = ["-1.13", "-1.81", "-3.13", "-.79", "-1.74", "-.85"]

# Расчет доверительных интервалов
z_score = 1.96
conf_intervals = [
    (md - z_score * s, md + z_score * s) for md, s in zip(mean_diff, se)
]

# Построение графика
plt.figure(figsize=(10, 6))
for i, (group, ci, p, h) in enumerate(zip(groups, conf_intervals, p_values, hedges_g)):
    plt.plot(ci, [i, i], color="skyblue")
    plt.scatter(mean_diff[i], i, color="blue")
    plt.text(ci[1] + 0.05, i, f"p={p}\nHedges' g={h}", va='center')

# Элементы оформления
plt.yticks(range(len(groups)), groups)
plt.axvline(0, color='grey', linestyle='--')
plt.xlabel("Mean Difference")
plt.title("Games-Howell Posthoc Test Results (New)")
plt.grid(True)
plt.show()

# %%
# Данные для MTLD
groups_mtld = ["Group 1 vs Group 2", "Group 1 vs Group 3", "Group 1 vs Group 4", "Group 2 vs Group 3", "Group 2 vs Group 4", "Group 3 vs Group 4"]
mean_diff_mtld = [-29.418878, -62.866924, -91.678912, -33.448047, -62.260035, -28.811988]
se_mtld = [4.943951, 5.156825, 7.082474, 2.873149, 5.641239, 5.828702]
p_values_mtld = ["<.01", "<.01", "<.01", "<.01", "<.01", "<.01"]
hedges_g_mtld = ["-.85", "-1.33", "-1.67", "-.78", "-1.46", "-.56"]

# Расчет доверительных интервалов
z_score_mtld = 1.96
conf_intervals_mtld = [
    (md - z_score_mtld * s, md + z_score_mtld * s) for md, s in zip(mean_diff_mtld, se_mtld)
]

# Построение графика для MTLD
plt.figure(figsize=(10, 6))
for i, (group, ci, p, h) in enumerate(zip(groups_mtld, conf_intervals_mtld, p_values_mtld, hedges_g_mtld)):
    plt.plot(ci, [i, i], color="skyblue")
    plt.scatter(mean_diff_mtld[i], i, color="blue")
    plt.text(ci[1] + 0.05, i, f"p={p}\nHedges' g={h}", va='center')

# Элементы оформления
plt.yticks(range(len(groups_mtld)), groups_mtld)
plt.axvline(0, color='grey', linestyle='--')
plt.xlabel("Mean Difference")
plt.title("Games-Howell Posthoc Test Results for MTLD")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Ваши результаты для MTLD
groups_mtld = ["Group 1 vs Group 2", "Group 1 vs Group 3", "Group 1 vs Group 4", "Group 2 vs Group 3", "Group 2 vs Group 4", "Group 3 vs Group 4"]
mean_diff_mtld = [-11.931941, -29.536645, -43.584973, -17.604705, -31.653033, -14.048328]
se_mtld = [3.241465, 3.349166, 3.852501, 1.558868, 2.460675, 2.600911]
p_values_mtld = ["<.01", "<.01", "<.01", "<.01", "<.01", "<.01"]
hedges_g_mtld = ["-.64", "-1.13", "-1.78", "-.76", "-1.54", "-.53"]

# Confidence intervals
conf_intervals_mtld = [(md - 1.96 * s, md + 1.96 * s) for md, s in zip(mean_diff_mtld, se_mtld)]

# Plotting
plt.figure(figsize=(10, 6))
for i, (group, ci, p, h) in enumerate(
    zip(groups_mtld, conf_intervals_mtld, p_values_mtld, hedges_g_mtld)
):
    plt.plot(ci, [i, i], color="skyblue")
    plt.scatter(mean_diff_mtld[i], i, color="blue")
    plt.text(ci[1] + 0.05, i, f"p={p}\nHedges' g={h}", va='center')

# Formatting
plt.yticks(range(len(groups_mtld)), groups_mtld)
plt.axvline(0, color='grey', linestyle='--')
plt.xlabel("Mean Difference")
plt.title("Games-Howell Posthoc Test Results for MTLD")
plt.grid(True)
plt.show()
